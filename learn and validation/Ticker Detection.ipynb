# %%
pip install natasha
# Out:
# Collecting natasha
#   Obtaining dependency information for natasha from https://files.pythonhosted.org/packages/32/9c/bb9d33c13564bcc939bb727087ef51b16ed3b49cc3b8fdec07c87b02f1de/natasha-1.6.0-py3-none-any.whl.metadata
#   Using cached natasha-1.6.0-py3-none-any.whl.metadata (23 kB)
# Collecting pymorphy2 (from natasha)
#   Obtaining dependency information for pymorphy2 from https://files.pythonhosted.org/packages/07/57/b2ff2fae3376d4f3c697b9886b64a54b476e1a332c67eee9f88e7f1ae8c9/pymorphy2-0.9.1-py3-none-any.whl.metadata
#   Using cached pymorphy2-0.9.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting razdel>=0.5.0 (from natasha)
#   Obtaining dependency information for razdel>=0.5.0 from https://files.pythonhosted.org/packages/15/2c/664223a3924aa6e70479f7d37220b3a658765b9cfe760b4af7ffdc50d38f/razdel-0.5.0-py3-none-any.whl.metadata
#   Using cached razdel-0.5.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting navec>=0.9.0 (from natasha)
#   Obtaining dependency information for navec>=0.9.0 from https://files.pythonhosted.org/packages/bc/c1/771ec5565f0ce24874d7fd325b429f9caa80517a40d2e4ce5705120591f3/navec-0.10.0-py3-none-any.whl.metadata
#   Using cached navec-0.10.0-py3-none-any.whl.metadata (21 kB)
# Collecting slovnet>=0.6.0 (from natasha)
#   Obtaining dependency information for slovnet>=0.6.0 from https://files.pythonhosted.org/packages/7c/32/d5aff64e3d51ec4021674215680f16b7d2907860c6443b0d058579ac7d59/slovnet-0.6.0-py3-none-any.whl.metadata
#   Using cached slovnet-0.6.0-py3-none-any.whl.metadata (34 kB)
# Collecting yargy>=0.16.0 (from natasha)
#   Obtaining dependency information for yargy>=0.16.0 from https://files.pythonhosted.org/packages/b7/55/d065a9812c619889fbe01a1863743ee45f7c60c462fc95b19576972ee9e4/yargy-0.16.0-py3-none-any.whl.metadata
#   Using cached yargy-0.16.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting ipymarkup>=0.8.0 (from natasha)
#   Obtaining dependency information for ipymarkup>=0.8.0 from https://files.pythonhosted.org/packages/bf/9b/bf54c98d50735a4a7c84c71e92c5361730c878ebfe903d2c2d196ef66055/ipymarkup-0.9.0-py3-none-any.whl.metadata
#   Using cached ipymarkup-0.9.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: intervaltree>=3 in c:\games\123\lib\site-packages (from ipymarkup>=0.8.0->natasha) (3.1.0)
# Requirement already satisfied: numpy in c:\games\123\lib\site-packages (from navec>=0.9.0->natasha) (1.24.3)
# Collecting dawg-python>=0.7.1 (from pymorphy2->natasha)
#   Obtaining dependency information for dawg-python>=0.7.1 from https://files.pythonhosted.org/packages/6a/84/ff1ce2071d4c650ec85745766c0047ccc3b5036f1d03559fd46bb38b5eeb/DAWG_Python-0.7.2-py2.py3-none-any.whl.metadata
#   Using cached DAWG_Python-0.7.2-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2->natasha)
#   Obtaining dependency information for pymorphy2-dicts-ru<3.0,>=2.4 from https://files.pythonhosted.org/packages/3a/79/bea0021eeb7eeefde22ef9e96badf174068a2dd20264b9a378f2be1cdd9e/pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl.metadata
#   Using cached pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting docopt>=0.6 (from pymorphy2->natasha)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\games\123\lib\site-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha) (2.4.0)
# Using cached natasha-1.6.0-py3-none-any.whl (34.4 MB)
# Using cached ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Using cached navec-0.10.0-py3-none-any.whl (23 kB)
# Using cached razdel-0.5.0-py3-none-any.whl (21 kB)
# Using cached slovnet-0.6.0-py3-none-any.whl (46 kB)
# Using cached yargy-0.16.0-py3-none-any.whl (33 kB)
# Using cached pymorphy2-0.9.1-py3-none-any.whl (55 kB)
# Using cached DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Using cached pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
# Installing collected packages: razdel, pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2, navec, yargy, slovnet, ipymarkup, natasha
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 ipymarkup-0.9.0 natasha-1.6.0 navec-0.10.0 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 razdel-0.5.0 slovnet-0.6.0 yargy-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Obtaining dependency information for rapidfuzz from https://files.pythonhosted.org/packages/c9/5a/d00e1f63564050a20279015acb29ecaf41646adfacc6ce2e1e450f7f2633/rapidfuzz-3.13.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading rapidfuzz-3.13.0-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.6 MB 660.6 kB/s eta 0:00:03
#    -- ------------------------------------- 0.1/1.6 MB 1.3 MB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.6 MB 2.2 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.6 MB 2.2 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.6 MB 3.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.6 MB 2.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.6 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
from pymorphy2 import MorphAnalyzer
from rapidfuzz import fuzz

segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
ner_tagger = NewsNERTagger(emb)
morph = MorphAnalyzer()

def fetch_moex_tickers():
    url = 'https://iss.moex.com/iss/engines/stock/markets/shares/securities.json'
    response = requests.get(url)
    data = response.json()
    securities = data['securities']['data']
    columns = data['securities']['columns']
    df = pd.DataFrame(securities, columns=columns)
    df_filtered = df[['SECID', 'SHORTNAME', 'SECNAME']].dropna()
    company_to_ticker = {}
    for _, row in df_filtered.iterrows():
        names = [row['SECNAME'], row['SHORTNAME']]
        for name in names:
            company_to_ticker[name.lower()] = row['SECID']
    return company_to_ticker

def normalize_text(text):
    return ' '.join([morph.parse(word)[0].normal_form for word in text.split()])

def extract_company_names(text):
    doc = Doc(text)
    doc.segment(segmenter)
    doc.tag_ner(ner_tagger)
    for span in doc.spans:
        span.normalize(morph_vocab)
    orgs_normalized = [span.normal for span in doc.spans if span.type == 'ORG']
    orgs_original = [span.text for span in doc.spans if span.type == 'ORG']
    
    # Удаляем шумовые фразы
    stopwords = {"сд", "совет директоров", "акционеров", "мсфо"} 
    result = []
    for original, normalized in zip(orgs_original, orgs_normalized):
        norm_text = normalized.lower()
        if norm_text not in stopwords:
            print(f"Original: {original} -> Normalized: {normalized}")
            result.append(norm_text)
    return result

def get_ticker_from_text(text, company_to_ticker):
    orgs = extract_company_names(text)
    for org in orgs:
        org_norm = normalize_text(org)
        best_match = None
        best_score = 0
        for key, ticker in company_to_ticker.items():
            score = fuzz.partial_ratio(org_norm, key)
            if score > best_score and score > 80: 
                best_match = (key, ticker)
                best_score = score
        if best_match:
            return best_match
    return None, None

# Example usage
if __name__ == "__main__":
    sample_text = """
Газпром что-то там вообще такое
"""
    company_to_ticker = fetch_moex_tickers()
    company_name, ticker = get_ticker_from_text(sample_text, company_to_ticker)
    if ticker:
        print(f"✅ Extracted Company Name: {company_name}")
        print(f"✅ Extracted Ticker: {ticker}")
    else:
        print("❌ No matching company or ticker found.")
# Out:
# Original: Газпром -> Normalized: Газпром
# ✅ Extracted Company Name: "газпром" (пао) ао
# ✅ Extracted Ticker: GAZP

# %%
file_path = r"C:\Users\Карпенко\ВКР Карпенко\data makeup\filtered_interfax_data.xlsx"

# Загружаем Excel-файл
df = pd.read_excel(file_path)

# Фильтруем строки, где Label=1
filtered_df = df[df['Label'] == 1]

# Выводим первые строки для проверки
filtered_df
# Out:
#                      Дата                                              Текст  \
# 6     2025-01-30 13:09:25  🍷**EBITDA LTM "Новабев групп" на 30 июня 2024 ...
# 8     2025-01-30 11:39:26  🔺**"Соллерс" поднял пороговое значение учитыва...
# 9     2025-01-30 11:27:51  🗓**"НОВАТЭК" 6 февраля проведет сбор заявок на...
# 10    2025-01-30 11:02:33  **Минфин не слышал о планах "Транснефти" снизи...
# 13    2025-01-30 08:02:19  **💰SoftBank Group ведет переговоры об инвестиц...
# ...                   ...                                                ...
# 1504  2025-04-01 08:21:01  **Роснано допустило техдефолт по купону облига...
# 1508  2025-04-01 07:14:17  🗓**Совет директоров "Новабев Групп" 2 апреля р...
# 1512  2025-04-01 07:03:16  **"Циан" одновременно со стартом торгов на Мос...
# 1513  2025-04-01 07:00:48  **"Циан" в IV квартале нарастил выручку на 5%,...
# 1514  2025-04-01 06:36:27  🛒**ГК "О'Кей" в 2024 году увеличила EBITDA на ...
#
#       Label
# 6       1.0
# 8       1.0
# 9       1.0
# 10      1.0
# 13      1.0
# ...     ...
# 1504    1.0
# 1508    1.0
# 1512    1.0
# 1513    1.0
# 1514    1.0
#
# [379 rows x 3 columns]

# %%
correctness = []

for index, row in filtered_df.iterrows():
    print(f"\n📰 News:\n{row['Текст']}")
    print(f"🔎 Extracted Ticker: {row['Ticker']}")
    
    user_input = input("0 or 1")
    
    if user_input not in ['0', '1']:
        print("Error")
        user_input = '0'
    
    correctness.append(int(user_input))

df_filtered['Correct'] = correctness

# Сохраняем результат
output_path = r"C:\Users\Карпенко\ВКР Карпенко\model\filtered_with_tickers_corrected.xlsx"
df_filtered.to_excel(output_path, index=False)

# %% [markdown]
# ##  error correction

# %%
# Подсчет точности
total = len(df_filtered)
correct = df_filtered['Correct'].sum()
accuracy = correct / total

print(f"📊 Accuracy (точность): {accuracy:.4f} ({correct}/{total})")
# Out:
# 📊 Accuracy (точность): 0.7018 (266/379)

# %%
df_filtered = pd.read_excel(r"C:\Users\Карпенко\ВКР Карпенко\model\filtered_with_tickers_corrected.xlsx")
df_filtered
# Out:
#                     Дата                                              Текст  \
# 0    2025-01-30 13:09:25  🍷**EBITDA LTM "Новабев групп" на 30 июня 2024 ...
# 1    2025-01-30 11:39:26  🔺**"Соллерс" поднял пороговое значение учитыва...
# 2    2025-01-30 11:27:51  🗓**"НОВАТЭК" 6 февраля проведет сбор заявок на...
# 3    2025-01-30 11:02:33  **Минфин не слышал о планах "Транснефти" снизи...
# 4    2025-01-30 08:02:19  **💰SoftBank Group ведет переговоры об инвестиц...
# ..                   ...                                                ...
# 374  2025-04-01 08:21:01  **Роснано допустило техдефолт по купону облига...
# 375  2025-04-01 07:14:17  🗓**Совет директоров "Новабев Групп" 2 апреля р...
# 376  2025-04-01 07:03:16  **"Циан" одновременно со стартом торгов на Мос...
# 377  2025-04-01 07:00:48  **"Циан" в IV квартале нарастил выручку на 5%,...
# 378  2025-04-01 06:36:27  🛒**ГК "О'Кей" в 2024 году увеличила EBITDA на ...
#
#      Label     Ticker  Correct
# 0        1       BELU        1
# 1        1       SVAV        1
# 2        1       NVTK        1
# 3        1      TRNFP        1
# 4        1       BSPB        0
# ..     ...        ...      ...
# 374      1  Not found        0
# 375      1       BELU        1
# 376      1       CNRU        1
# 377      1       CNRU        1
# 378      1       OKEY        1
#
# [379 rows x 5 columns]

# %% [markdown]
# ## error correction

# %%
import re
import requests
import pandas as pd
from natasha import Segmenter, NewsNERTagger, NewsEmbedding, MorphVocab, Doc
from pymorphy2 import MorphAnalyzer
from rapidfuzz import fuzz

segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
ner_tagger = NewsNERTagger(emb)
morph = MorphAnalyzer()

def clean_company_name(name):
    keywords_to_remove = ['plc', 'ipjsc', 'оао', 'зао', 'пиф', 'international public js com', 'мкпао',
                         'адр', 'corporate center', 'группа', 'пао']
    words = name.lower().split()
    cleaned = ' '.join([w for w in words if w not in keywords_to_remove])
    return cleaned


def fetch_moex_tickers():
    url = 'https://iss.moex.com/iss/engines/stock/markets/shares/securities.json'
    response = requests.get(url)
    data = response.json()
    securities = data['securities']['data']
    columns = data['securities']['columns']
    df = pd.DataFrame(securities, columns=columns)
    
    df_filtered = df[['SECID', 'SHORTNAME', 'SECNAME', 'LATNAME']].dropna()
    df_filtered = df_filtered[df_filtered['SECID'].apply(lambda x: len(str(x)) <= 6)]
    
    company_to_ticker = {}
    for _, row in df_filtered.iterrows():
        names = [row['SECNAME'], row['SHORTNAME'], row['LATNAME']]
        for name in names:
            company_to_ticker[name.lower()] = row['SECID']
    return company_to_ticker


def normalize_text(text):
    return ' '.join([morph.parse(word)[0].normal_form for word in text.split()])

def extract_company_names(text):
    doc = Doc(text)
    doc.segment(segmenter)
    doc.tag_ner(ner_tagger)
    for span in doc.spans:
        span.normalize(morph_vocab)
    orgs_normalized = [span.normal for span in doc.spans if span.type == 'ORG']
    orgs_original = [span.text for span in doc.spans if span.type == 'ORG']
    
    stopwords = {"сд", "совет директоров", "акционеров", "мсфо", 'цб',
                "мосбиржа", 'банк россии', 'рбк', 'московская биржа', 'ук'}
    result = []
    for original, normalized in zip(orgs_original, orgs_normalized):
        norm_text = normalized.lower()
        if norm_text not in stopwords:
            print(f"Original: {original} -> Normalized: {normalized}")
            result.append(norm_text)

    if "лента" in text.lower() and not any("лента" in org for org in result):
        result.append("лента")
        
    if "самолет" in text.lower() and not any("самолет" in org for org in result):
        result.append("самолет")

    return result


def replace_sber_with_sberbank(text):
    text = re.sub(r'\bСбер\b(?=\s|$)', 'Сбербанк', text)
    text = re.sub(r'\bТ[ -]Банк\b', 'Т-Технологии', text, flags=re.IGNORECASE)
    text = re.sub(r'\bТ[ -]Банка\b', 'Т-Технологии', text, flags=re.IGNORECASE)
    text = re.sub(r'["«]?\s*Лента\s*["»]?', 'Лента АО', text, flags=re.IGNORECASE)
    return text

def get_ticker_from_text(text, company_to_ticker):
    text = replace_sber_with_sberbank(text)
    orgs = extract_company_names(text)
    
    for org in orgs:
        org_norm = normalize_text(org)
        if org_norm.lower() in ["vk", "вк", "вконтакте", "vk tech"]:
            return ("VK", "VKCO")
        if org_norm.lower() in ["x5", "x5 group", "х5", "икс5", "икс 5"]:
            return ("X5", "X5")
        if org_norm.lower() in ["магнит"]:
            return ('ПАО "Магнит"' , "MGNT")
        if org_norm.lower() in ["мать и дитя", "матери и дети", "md medical group"]:
            return ('ПАО "Мать и дитя"', "MDMG")
        if org_norm.lower() in ["cамолет"]:
            return ('Самолет', "SMLT")

        
        org_cleaned = clean_company_name(org_norm)
        best_match = None
        best_score = 0
        for key, ticker in company_to_ticker.items():
            key_cleaned = clean_company_name(key)
            score = fuzz.partial_ratio(org_cleaned, key_cleaned)
            if score > best_score and score > 85:
                best_match = (key, ticker)
                best_score = score
        if best_match:
            return best_match
    
    stopwords = {"сд", "совет директоров", "акционеров", "мсфо", 'цб',
                 'мосбиржа', 'банк россии', 'рбк', 'московская биржа'}
    for org in orgs:
        if org.lower() not in stopwords:
            return (org, "N/A")
    
    if "ооо" in text.lower():
        return ("ООО", "N/A")
    elif any(keyword in text.lower() for keyword in ["plc", "ltd", "limited", "inc", "corp", "company"]):
        return ("Иностранная компания", "N/A")
    else:
        return (None, None)



if __name__ == "__main__":
    sample_text = """
**"Самолет" в 2024 году увеличил EBITDA на 16%**

Девелопер "Самолет" в 2024 году увеличил EBITDA по МСФО на 16%, до 83,6 млрд рублей.

Согласно отчетности, чистая прибыль упала в 3 раза, до 8,2 млрд рублей.

Накануне аналитики ожидали EBITDA "Самолета" в диапазоне 74-78,3 млрд рублей, чистую прибыль - 5-7,1 млрд рублей.

@ifax_go
    """
    company_to_ticker = fetch_moex_tickers()
    company_name, ticker = get_ticker_from_text(sample_text, company_to_ticker)
    if ticker:
        print(f"✅ Extracted Company Name: {company_name}")
        print(f"✅ Extracted Ticker: {ticker}")
    else:
        print("❌ No matching company or ticker found.")
# Out:
# ✅ Extracted Company Name: гк самолет ао
# ✅ Extracted Ticker: SMLT

# %%
df = df_filtered[['Текст']].copy()

company_to_ticker = fetch_moex_tickers()

df['Ticker'] = df['Текст'].apply(lambda x: get_ticker_from_text(x, company_to_ticker)[1])

output_path = r"C:\Users\Карпенко\ВКР Карпенко\data markup\filtered_with_tickers_2.xlsx"
df.to_excel(output_path, index=False)

print(f" {output_path}")
# Out:
# Original: Новабев групп -> Normalized: Новабев групп
# Original: Новабев Групп -> Normalized: Новабев Групп
# Original: LTM -> Normalized: LTM
# Original: LTM -> Normalized: LTM
# Original: Соллерс -> Normalized: Соллерс
# Original: ПАО "Соллерс" -> Normalized: ПАО "Соллерс"
# Original: Соллерса -> Normalized: Соллерса
# Original: Соллерс -> Normalized: Соллерс
# Original: НОВАТЭК -> Normalized: НОВАТЭК
# Original: ПАО "НОВАТЭК" -> Normalized: ПАО "НОВАТЭК"
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Банка России -> Normalized: Банка России
# Original: Минфин -> Normalized: Минфин
# Original: Транснефти -> Normalized: Транснефти
# Original: Министерство финансов -> Normalized: Министерство финансов
# Original: Транснефти -> Normalized: Транснефти
# Original: ПАО "Транснефть" -> Normalized: ПАО "Транснефть"
# Original: Транснефти -> Normalized: Транснефти
# Original: Транснефть -> Normalized: Транснефть
# Original: SoftBank Group -> Normalized: SoftBank Group
# Original: Financial Times -> Normalized: Financial Times
# Original: OpenAI -> Normalized: OpenAI
# Original: SoftBank -> Normalized: SoftBank
# Original: Oracle Corp -> Normalized: Oracle Corp
# Original: MGX -> Normalized: MGX
# Original: СП -> Normalized: СП
# Original: Stargate -> Normalized: Stargate
# Original: OpenAI -> Normalized: OpenAI
# Original: SoftBank -> Normalized: SoftBank
# Original: FT -> Normalized: FT
# Original: SoftBank -> Normalized: SoftBank
# Original: OpenAI -> Normalized: OpenAI
# Original: РусГидро -> Normalized: РусГидро
# Original: Мосбирже -> Normalized: Мосбирже
# Original: РусГидро -> Normalized: РусГидро
# Original: РусГидро -> Normalized: РусГидро
# Original: ПАО "РусГидро" -> Normalized: ПАО "РусГидро"
# Original: РусГидро -> Normalized: РусГидро
# Original: РусГидро -> Normalized: РусГидро
# Original: РусГидро -> Normalized: РусГидро
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: Российского национального коммерческого банка (РНКБ) -> Normalized: Российского национального коммерческого банка (РНКБ)
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: Семейного банка -> Normalized: Семейного банка
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: РНКБ -> Normalized: РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: ХКФ -> Normalized: ХКФ
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: ХКФ -> Normalized: ХКФ
# Original: Хоум банк -> Normalized: Хоум банк
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: АО "Хоум капитал -> Normalized: АО "Хоум капитал
# Original: ХКФ банка -> Normalized: ХКФ банка
# Original: Хоум капитала -> Normalized: Хоум капитала
# Original: ХКФ -> Normalized: ХКФ
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: ХКФ -> Normalized: ХКФ
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: Хоум капитала -> Normalized: Хоум капитала
# Original: ХКФ банка -> Normalized: ХКФ банка
# Original: Монтажспецстрой -> Normalized: Монтажспецстрой
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: Инарктика -> Normalized: Инарктика
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: ПАО -> Normalized: ПАО
# Original: Ros Agro Plc -> Normalized: Ros Agro Plc
# Original: Русагро -> Normalized: Русагро
# Original: Газпрома -> Normalized: Газпрома
# Original: Nord Stream 2 AG -> Normalized: Nord Stream 2 AG
# Original: Газпрома -> Normalized: Газпрома
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Nord Stream 2 AG -> Normalized: Nord Stream 2 AG
# Original: Газпрома -> Normalized: Газпрома
# Original: Nord Stream 2 AG -> Normalized: Nord Stream 2 AG
# Original: ООО "Тами и Ко -> Normalized: ООО "Тами и Ко
# Original: ПАО "Хэндерсон Фэшн Групп -> Normalized: ПАО "Хэндерсон Фэшн Групп
# Original: Henderson -> Normalized: Henderson
# Original: Cian Plc -> Normalized: Cian Plc
# Original: Х5 -> Normalized: Х5
# Original: ООО "Икс 5 Финанс -> Normalized: ООО "Икс 5 Финанс
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Синара -> Normalized: Синара
# Original: Sber CIB -> Normalized: Sber CIB
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: УК "Горизонт" -> Normalized: УК "Горизонт"
# Original: ПАО "Корпоративный центр ИКС 5 -> Normalized: ПАО "Корпоративный центр ИКС 5
# Original: Пятерочка -> Normalized: Пятерочка
# Original: Перекресток -> Normalized: Перекресток
# Original: Чижик -> Normalized: Чижик
# Original: Пятерочка -> Normalized: Пятерочка
# Original: Перекресток -> Normalized: Перекресток
# Original: X5 Group -> Normalized: X5 Group
# Original: Циан -> Normalized: Циан
# Original: Циан -> Normalized: Циан
# Original: МКПАО -> Normalized: МКПАО
# Original: Циан Технолоджи Лтд -> Normalized: Циан Технолоджи Лтд
# Original: Циан -> Normalized: Циан
# Original: Циан -> Normalized: Циан
# Original: Cian Technology Ltd -> Normalized: Cian Technology Ltd
# Original: Cian Plc -> Normalized: Cian Plc
# Original: Cian Technology Ltd -> Normalized: Cian Technology Ltd
# Original: МКАО "Циан -> Normalized: МКАО "Циан
# Original: Cian PLC -> Normalized: Cian PLC
# Original: Циан -> Normalized: Циан
# Original: Globaltrans Investment PLC -> Normalized: Globaltrans Investment PLC
# Original: Adaptive Capital Limited -> Normalized: Adaptive Capital Limited
# Original: GDR Globaltrans -> Normalized: GDR Globaltrans
# Original: Globaltrans -> Normalized: Globaltrans
# Original: Fix Price -> Normalized: Fix Price
# Original: АО "Фикс Прайс -> Normalized: АО "Фикс Прайс
# Original: ООО "Бэст Прайс -> Normalized: ООО "Бэст Прайс
# Original: Fix Price -> Normalized: Fix Price
# Original: ЕГРЮЛ -> Normalized: ЕГРЮЛ
# Original: ООО "Бэст Прайс Экспорт -> Normalized: ООО "Бэст Прайс Экспорт
# Original: Fix Price plc -> Normalized: Fix Price plc
# Original: АО "Фикс Прайс -> Normalized: АО "Фикс Прайс
# Original: CEO -> Normalized: CEO
# Original: МосБирже -> Normalized: МосБирже
# Original: ООО "Бэст прайс -> Normalized: ООО "Бэст прайс
# Original: Fix Price -> Normalized: Fix Price
# Original: МосБирже -> Normalized: МосБирже
# Original: Росбанк -> Normalized: Росбанк
# Original: Росбанк -> Normalized: Росбанк
# Original: Росбанк -> Normalized: Росбанк
# Original: Т -> Normalized: Т
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: Русагро -> Normalized: Русагро
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: Арбитражный суд -> Normalized: Арбитражный суд
# Original: Ros Agro Plc -> Normalized: Ros Agro Plc
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: Ros Agro Plc -> Normalized: Ros Agro Plc
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: Арбитражный суд -> Normalized: Арбитражный суд
# Original: Ros Agro Plc -> Normalized: Ros Agro Plc
# Original: Х5 -> Normalized: Х5
# Original: ООО "Икс 5 Финанс -> Normalized: ООО "Икс 5 Финанс
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Синара -> Normalized: Синара
# Original: Sber CIB -> Normalized: Sber CIB
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: УК "Горизонт" -> Normalized: УК "Горизонт"
# Original: ПАО "Корпоративный Центр Икс 5 -> Normalized: ПАО "Корпоративный Центр Икс 5
# Original: ruAAA -> Normalized: ruAAA
# Original: Эксперт РА -> Normalized: Эксперт РА
# Original: AAA(RU) -> Normalized: AAA(RU)
# Original: АКРА -> Normalized: АКРА
# Original: Skillbox Holding Limited -> Normalized: Skillbox Holding Limited
# Original: ЕГРЮЛ -> Normalized: ЕГРЮЛ
# Original: МКАО "Скилбокс Холдинг -> Normalized: МКАО "Скилбокс Холдинг
# Original: МКАО -> Normalized: МКАО
# Original: Скилбокс Холдинг -> Normalized: Скилбокс Холдинг
# Original: VK -> Normalized: VK
# Original: Skillbox Holding -> Normalized: Skillbox Holding
# Original: Skillbox -> Normalized: Skillbox
# Original: VK -> Normalized: VK
# Original: АО "ВК Технологии" -> Normalized: АО "ВК Технологии"
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Санкт-Петербург -> Normalized: Санкт-Петербург
# Original: ЕвроТранс -> Normalized: ЕвроТранс
# Original: ПАО "ЕвроТранс" -> Normalized: ПАО "ЕвроТранс"
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ТГК-2 -> Normalized: ТГК-2
# Original: ПАО "ТГК-2" -> Normalized: ПАО "ТГК-2"
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Банка России -> Normalized: Банка России
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Росбанка -> Normalized: Росбанка
# Original: Росбанка -> Normalized: Росбанка
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Росбанка -> Normalized: Росбанка
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Росбанк -> Normalized: Росбанк
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: ТКС Холдинг -> Normalized: ТКС Холдинг
# Original: Т-Банком -> Normalized: Т-Банком
# Original: Росбанка -> Normalized: Росбанка
# Original: Morgan Stanley -> Normalized: Morgan Stanley
# Original: Morgan Stanley -> Normalized: Morgan Stanley
# Original: Morgan Stanley -> Normalized: Morgan Stanley
# Original: СМЗ -> Normalized: СМЗ
# Original: Генпрокуратуры -> Normalized: Генпрокуратуры
# Original: ОАО "Соликамский магниевый завод" (СМЗ) -> Normalized: ОАО "Соликамский магниевый завод" (СМЗ)
# Original: Росатом -> Normalized: Росатом
# Original: Росатомом -> Normalized: Росатомом
# Original: Генпрокуратуры -> Normalized: Генпрокуратуры
# Original: ООО "Тами и Ко -> Normalized: ООО "Тами и Ко
# Original: ПАО "Хэндерсон Фэшн Групп -> Normalized: ПАО "Хэндерсон Фэшн Групп
# Original: Henderson -> Normalized: Henderson
# Original: Taiwan Semiconductor Manufacturing Company -> Normalized: Taiwan Semiconductor Manufacturing Company
# Original: CNBC -> Normalized: CNBC
# Original: TSMC -> Normalized: TSMC
# Original: Taiex -> Normalized: Taiex
# Original: Bank of New York Mellon -> Normalized: Bank of New York Mellon
# Original: МКАО "Скилбокс Холдинг -> Normalized: МКАО "Скилбокс Холдинг
# Original: МКАО -> Normalized: МКАО
# Original: Скилбокс Холдинг -> Normalized: Скилбокс Холдинг
# Original: VK -> Normalized: VK
# Original: Mail.ru Group -> Normalized: Mail.ru Group
# Original: Skillbox -> Normalized: Skillbox
# Original: GeekBrains -> Normalized: GeekBrains
# Original: Skillbox Limited -> Normalized: Skillbox Limited
# Original: Skillbox -> Normalized: Skillbox
# Original: IT-предпринимателя -> Normalized: IT-предпринимателя
# Original: Almaz Capital -> Normalized: Almaz Capital
# Original: ЕГРЮЛ -> Normalized: ЕГРЮЛ
# Original: ООО "Скилбокс" -> Normalized: ООО "Скилбокс"
# Original: ООО "Гикбреинс" -> Normalized: ООО "Гикбреинс"
# Original: Skillbox Holding Limited -> Normalized: Skillbox Holding Limited
# Original: VK -> Normalized: VK
# Original: Skillbox -> Normalized: Skillbox
# Original: Skillbox -> Normalized: Skillbox
# Original: EdТech-рынке -> Normalized: EdТech-рынке
# Original: VK -> Normalized: VK
# Original: АО "ВК Технологии" -> Normalized: АО "ВК Технологии"
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Рунете -> Normalized: Рунете
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Магнит -> Normalized: Магнит
# Original: ПАО "Магнит" -> Normalized: ПАО "Магнит"
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: БК "Регион" -> Normalized: БК "Регион"
# Original: Россельхозбанк -> Normalized: Россельхозбанк
# Original: Совкомфлот -> Normalized: Совкомфлот
# Original: Совкомфлот -> Normalized: Совкомфлот
# Original: Минфин -> Normalized: Минфин
# Original: Совкомфлота -> Normalized: Совкомфлота
# Original: Смарттехгрупп -> Normalized: Смарттехгрупп
# Original: Промсвязьбанка -> Normalized: Промсвязьбанка
# Original: ПАО "Смарттехгрупп" (СТГ) -> Normalized: ПАО "Смарттехгрупп" (СТГ)
# Original: CarMoney -> Normalized: CarMoney
# Original: Промсвязьбанка (ПСБ) -> Normalized: Промсвязьбанка (ПСБ)
# Original: СТГ -> Normalized: СТГ
# Original: ПСБ -> Normalized: ПСБ
# Original: Промсвязьбанк -> Normalized: Промсвязьбанк
# Original: СТГ -> Normalized: СТГ
# Original: Смарттехгрупп -> Normalized: Смарттехгрупп
# Original: СТГ -> Normalized: СТГ
# Original: Промсвязьбанка -> Normalized: Промсвязьбанка
# Original: Альфа-банк -> Normalized: Альфа-банк
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Альфа-банк -> Normalized: Альфа-банк
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: ООО "Финтех-платформа" -> Normalized: ООО "Финтех-платформа"
# Original: ЕГРЮЛ -> Normalized: ЕГРЮЛ
# Original: Сбера -> Normalized: Сбера
# Original: Альфа-банку -> Normalized: Альфа-банку
# Original: ООО "Финтех-платформа" -> Normalized: ООО "Финтех-платформа"
# Original: Сбербанка -> Normalized: Сбербанка
# Original: Альфа-банка -> Normalized: Альфа-банка
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Интерфакс -> Normalized: Интерфакс
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Альфа-банк -> Normalized: Альфа-банк
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: QR-кодом -> Normalized: QR-кодом
# Original: Национальная система платежных карт (НСПК) -> Normalized: Национальная система платежных карт (НСПК)
# Original: Займера -> Normalized: Займера
# Original: МФК -> Normalized: МФК
# Original: Займер -> Normalized: Займер
# Original: МФК -> Normalized: МФК
# Original: Займера -> Normalized: Займера
# Original: Займера -> Normalized: Займера
# Original: X5 -> Normalized: X5
# Original: ПАО "Корпоративный центр ИКС 5" (X5) -> Normalized: ПАО "Корпоративный центр ИКС 5" (X5)
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Перекрестка -> Normalized: Перекрестка
# Original: Пятерочки -> Normalized: Пятерочки
# Original: X5 -> Normalized: X5
# Original: X5 Retail -> Normalized: X5 Retail
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: ХКФ -> Normalized: ХКФ
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: ХКФ -> Normalized: ХКФ
# Original: Хоум банк -> Normalized: Хоум банк
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: СИБУР -> Normalized: СИБУР
# Original: СИБУР Холдинга -> Normalized: СИБУР Холдинга
# Original: СИБУР Холдинга -> Normalized: СИБУР Холдинга
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Сбербанка -> Normalized: Сбербанка
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Сбербанка -> Normalized: Сбербанка
# Original: ИФ -> Normalized: ИФ
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Nvidia -> Normalized: Nvidia
# Original: Nvidia Corp -> Normalized: Nvidia Corp
# Original: Арбитражный суд -> Normalized: Арбитражный суд
# Original: Борец -> Normalized: Борец
# Original: ООО " Борец Капитал -> Normalized: ООО " Борец Капитал
# Original: Генеральная прокуратура -> Normalized: Генеральная прокуратура
# Original: Арбитражный суд -> Normalized: Арбитражный суд
# Original: Борец -> Normalized: Борец
# Original: ПК -> Normalized: ПК
# Original: МКООО "Салтекор Инвестментс -> Normalized: МКООО "Салтекор Инвестментс
# Original: Международной коммерческой компании "Центр разработки нефтедобывающего оборудования -> Normalized: Международной коммерческой компании "Центр разработки нефтедобывающего оборудования
# Original: General Motors -> Normalized: General Motors
# Original: General Motors Co. (GM) -> Normalized: General Motors Co. (GM)
# Original: GM -> Normalized: GM
# Original: GM -> Normalized: GM
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ЦФА -> Normalized: ЦФА
# Original: НРД -> Normalized: НРД
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Национального расчетного депозитария (НРД) -> Normalized: Национального расчетного депозитария (НРД)
# Original: НРД -> Normalized: НРД
# Original: ВТБ -> Normalized: ВТБ
# Original: ВТБ -> Normalized: ВТБ
# Original: ВТБ -> Normalized: ВТБ
# Original: АДР -> Normalized: АДР
# Original: Cian -> Normalized: Cian
# Original: Cian Plc -> Normalized: Cian Plc
# Original: Циан -> Normalized: Циан
# Original: Cian -> Normalized: Cian
# Original: МКПАО "Циан -> Normalized: МКПАО "Циан
# Original: Полюса -> Normalized: Полюса
# Original: Полюса -> Normalized: Полюса
# Original: Полюса -> Normalized: Полюса
# Original: АЛРОСА -> Normalized: АЛРОСА
# Original: АК "АЛРОСА" -> Normalized: АК "АЛРОСА"
# Original: Московской биржей -> Normalized: Московской биржей
# Original: Северсталь -> Normalized: Северсталь
# Original: Северсталь -> Normalized: Северсталь
# Original: Северстали -> Normalized: Северстали
# Original: Северсталь -> Normalized: Северсталь
# Original: Северстали -> Normalized: Северстали
# Original: Газпром -> Normalized: Газпром
# Original: Газпром капитал -> Normalized: Газпром капитал
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Магнит -> Normalized: Магнит
# Original: ПАО "Магнит" -> Normalized: ПАО "Магнит"
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Банка России -> Normalized: Банка России
# Original: Нидерландская Nebius Group -> Normalized: Нидерландская Nebius Group
# Original: Yandex N.V. -> Normalized: Yandex N.V.
# Original: ИИ-инфраструктуры -> Normalized: ИИ-инфраструктуры
# Original: Nebius -> Normalized: Nebius
# Original: Nebius -> Normalized: Nebius
# Original: Яндекса -> Normalized: Яндекса
# Original: Nebius -> Normalized: Nebius
# Original: АФК "Система" -> Normalized: АФК "Система"
# Original: АФК "Система" -> Normalized: АФК "Система"
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: АЛРОСА -> Normalized: АЛРОСА
# Original: АЛРОСА -> Normalized: АЛРОСА
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: РЖД -> Normalized: РЖД
# Original: ОАО "Российские железные дороги" (РЖД) -> Normalized: ОАО "Российские железные дороги" (РЖД)
# Original: РЖД -> Normalized: РЖД
# Original: ХК "Металлоинвест" -> Normalized: ХК "Металлоинвест"
# Original: ХК "Металлоинвест" -> Normalized: ХК "Металлоинвест"
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Металлоинвест -> Normalized: Металлоинвест
# Original: Fix Price -> Normalized: Fix Price
# Original: Fix Price plc -> Normalized: Fix Price plc
# Original: АО "Фикс Прайс -> Normalized: АО "Фикс Прайс
# Original: Fix Price -> Normalized: Fix Price
# Original: Русснефть -> Normalized: Русснефть
# Original: ПАО "Русснефть" -> Normalized: ПАО "Русснефть"
# Original: НК -> Normalized: НК
# Original: ФосАгро -> Normalized: ФосАгро
# Original: ФосАгро -> Normalized: ФосАгро
# Original: ФосАгро -> Normalized: ФосАгро
# Original: Черкизово -> Normalized: Черкизово
# Original: Черкизово -> Normalized: Черкизово
# Original: Черкизово -> Normalized: Черкизово
# Original: Промсвязьбанк -> Normalized: Промсвязьбанк
# Original: ПАО "Промсвязьбанк" -> Normalized: ПАО "Промсвязьбанк"
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: ПСБ -> Normalized: ПСБ
# Original: АКРА -> Normalized: АКРА
# Original: НОВАТЭКа -> Normalized: НОВАТЭКа
# Original: НОВАТЭКа -> Normalized: НОВАТЭКа
# Original: НОВАТЭКа -> Normalized: НОВАТЭКа
# Original: Черкизово -> Normalized: Черкизово
# Original: ПАО "Группа Черкизово -> Normalized: ПАО "Группа Черкизово
# Original: Норникеля -> Normalized: Норникеля
# Original: Норникеля -> Normalized: Норникеля
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Сбербанка -> Normalized: Сбербанка
# Original: СИБУР -> Normalized: СИБУР
# Original: ПАО "СИБУР Холдинг -> Normalized: ПАО "СИБУР Холдинг
# Original: МСК -> Normalized: МСК
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Ньютон инвестиции -> Normalized: Ньютон инвестиции
# Original: Банка России -> Normalized: Банка России
# Original: Норникеля -> Normalized: Норникеля
# Original: ГМК "Норильский никель -> Normalized: ГМК "Норильский никель
# Original: Норникеля -> Normalized: Норникеля
# Original: Норникель -> Normalized: Норникель
# Original: CFO -> Normalized: CFO
# Original: Х5 -> Normalized: Х5
# Original: ООО "Икс 5 Финанс -> Normalized: ООО "Икс 5 Финанс
# Original: Банка России -> Normalized: Банка России
# Original: ВБРР -> Normalized: ВБРР
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Держава -> Normalized: Держава
# Original: Синара -> Normalized: Синара
# Original: Sber CIB -> Normalized: Sber CIB
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: ИК "Горизонт" -> Normalized: ИК "Горизонт"
# Original: Экспобанк -> Normalized: Экспобанк
# Original: АКРА -> Normalized: АКРА
# Original: Газпром -> Normalized: Газпром
# Original: Газпром капитал -> Normalized: Газпром капитал
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Газпром -> Normalized: Газпром
# Original: Cian Plc -> Normalized: Cian Plc
# Original: Циан -> Normalized: Циан
# Original: АДР -> Normalized: АДР
# Original: Cian Plc -> Normalized: Cian Plc
# Original: МКПАО "Циан" -> Normalized: МКПАО "Циан"
# Original: АДР Cian Plc -> Normalized: АДР Cian Plc
# Original: Cian Plc -> Normalized: Cian Plc
# Original: Циан -> Normalized: Циан
# Original: Циан -> Normalized: Циан
# Original: МКПАО "Циан -> Normalized: МКПАО "Циан
# Original: Озон Фармацевтики -> Normalized: Озон Фармацевтики
# Original: РИИ -> Normalized: РИИ
# Original: ПАО "Озон Фармацевтика -> Normalized: ПАО "Озон Фармацевтика
# Original: Роснано -> Normalized: Роснано
# Original: ВУШ Холдинг -> Normalized: ВУШ Холдинг
# Original: Группа Позитив -> Normalized: Группа Позитив
# Original: Софтлайн -> Normalized: Софтлайн
# Original: Диасофт -> Normalized: Диасофт
# Original: Делимобиль -> Normalized: Делимобиль
# Original: МКПАО "Циан Технолоджи Лтд -> Normalized: МКПАО "Циан Технолоджи Лтд
# Original: ЕГРЮЛ -> Normalized: ЕГРЮЛ
# Original: Циан -> Normalized: Циан
# Original: МКПАО -> Normalized: МКПАО
# Original: Селигдар -> Normalized: Селигдар
# Original: Селигдар -> Normalized: Селигдар
# Original: Селигдар -> Normalized: Селигдар
# Original: ГК "Русагро" -> Normalized: ГК "Русагро"
# Original: ГК "Русагро" -> Normalized: ГК "Русагро"
# Original: Агро-Белогорье -> Normalized: Агро-Белогорье
# Original: МКАО "Циан -> Normalized: МКАО "Циан
# Original: МКПАО -> Normalized: МКПАО
# Original: ЕГРЮЛ -> Normalized: ЕГРЮЛ
# Original: Циан -> Normalized: Циан
# Original: МКПАО -> Normalized: МКПАО
# Original: Циан Технолоджи Лтд -> Normalized: Циан Технолоджи Лтд
# Original: Циан -> Normalized: Циан
# Original: Cian Technology Ltd -> Normalized: Cian Technology Ltd
# Original: Cian Plc -> Normalized: Cian Plc
# Original: Cian Technology Ltd -> Normalized: Cian Technology Ltd
# Original: Группы Аренадата -> Normalized: Группы Аренадата
# Original: ПАО "Группа Аренадата -> Normalized: ПАО "Группа Аренадата
# Original: Группы Аренадата -> Normalized: Группы Аренадата
# Original: LfL-выручка -> Normalized: LfL-выручка
# Original: УК -> Normalized: УК
# Original: Мать и дитя -> Normalized: Мать и дитя
# Original: МКПАО "МД Медикал Груп" (ГК "МД Медикал -> Normalized: МКПАО "МД Медикал Груп" (ГК "МД Медикал
# Original: МДМГ -> Normalized: МДМГ
# Original: Raiffeisen Bank International (RBI) -> Normalized: Raiffeisen Bank International (RBI)
# Original: Райффайзенбанка -> Normalized: Райффайзенбанка
# Original: CEO RBI -> Normalized: CEO RBI
# Original: RBI -> Normalized: RBI
# Original: Райффайзенбанка -> Normalized: Райффайзенбанка
# Original: Аэрофлота -> Normalized: Аэрофлота
# Original: Аэрофлота -> Normalized: Аэрофлота
# Original: Альфа-банка -> Normalized: Альфа-банка
# Original: Минфина -> Normalized: Минфина
# Original: Ренессанс капитала -> Normalized: Ренессанс капитала
# Original: Аэрофлота -> Normalized: Аэрофлота
# Original: Райффайзенбанка -> Normalized: Райффайзенбанка
# Original: RBI -> Normalized: RBI
# Original: RBI -> Normalized: RBI
# Original: Приорбанка -> Normalized: Приорбанка
# Original: RBI -> Normalized: RBI
# Original: Полюса -> Normalized: Полюса
# Original: Полюса -> Normalized: Полюса
# Original: Полюса -> Normalized: Полюса
# Original: ИБ "Синара -> Normalized: ИБ "Синара
# Original: Полюса -> Normalized: Полюса
# Original: Русагро -> Normalized: Русагро
# Original: Арбитражный суд -> Normalized: Арбитражный суд
# Original: Ros Agro Plc -> Normalized: Ros Agro Plc
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: Диасофта -> Normalized: Диасофта
# Original: ПАО "Диасофт" -> Normalized: ПАО "Диасофт"
# Original: ПАО "Аэрофлот" -> Normalized: ПАО "Аэрофлот"
# Original: Аэрофлота -> Normalized: Аэрофлота
# Original: Ros Agro -> Normalized: Ros Agro
# Original: Московской -> Normalized: Московской
# Original: Астанинской бирж -> Normalized: Астанинской бирж
# Original: Ros Agro Plc -> Normalized: Ros Agro Plc
# Original: Русагро -> Normalized: Русагро
# Original: Астанинской бирж -> Normalized: Астанинской бирж
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: Московской бирже -> Normalized: Московской бирже
# Original: RAGR -> Normalized: RAGR
# Original: Арбитражный суд -> Normalized: Арбитражный суд
# Original: Минсельхоза -> Normalized: Минсельхоза
# Original: Ros Agro Plc -> Normalized: Ros Agro Plc
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: Арбитражный апелляционный суд -> Normalized: Арбитражный апелляционный суд
# Original: Арбитражный суд -> Normalized: Арбитражный суд
# Original: Селигдара -> Normalized: Селигдара
# Original: Селигдара -> Normalized: Селигдара
# Original: Селигдар -> Normalized: Селигдар
# Original: Транснефти -> Normalized: Транснефти
# Original: Транснефти -> Normalized: Транснефти
# Original: Интерфаксом -> Normalized: Интерфаксом
# Original: Транснефть -> Normalized: Транснефть
# Original: Русал -> Normalized: Русал
# Original: ОК "Русал" -> Normalized: ОК "Русал"
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: Черкизово -> Normalized: Черкизово
# Original: Черкизово -> Normalized: Черкизово
# Original: Газпром -> Normalized: Газпром
# Original: Газпром капитал -> Normalized: Газпром капитал
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Газпром -> Normalized: Газпром
# Original: Акрона -> Normalized: Акрона
# Original: ПАО "Акрон" -> Normalized: ПАО "Акрон"
# Original: Акрон -> Normalized: Акрон
# Original: Акрона -> Normalized: Акрона
# Original: ПАО -> Normalized: ПАО
# Original: VK Tech -> Normalized: VK Tech
# Original: Банк -> Normalized: Банк
# Original: ПАО "ВК Технологии" (VK Tech -> Normalized: ПАО "ВК Технологии" (VK Tech
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: ВК Технологии -> Normalized: ВК Технологии
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ЦФА -> Normalized: ЦФА
# Original: НРД -> Normalized: НРД
# Original: Национального расчетного депозитария (НРД) -> Normalized: Национального расчетного депозитария (НРД)
# Original: НРД -> Normalized: НРД
# Original: РЖД -> Normalized: РЖД
# Original: РЖД -> Normalized: РЖД
# Original: РЖД -> Normalized: РЖД
# Original: Avito -> Normalized: Avito
# Original: АО "Авито Финанс -> Normalized: АО "Авито Финанс
# Original: Avito -> Normalized: Avito
# Original: Центробанком -> Normalized: Центробанком
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Avito -> Normalized: Avito
# Original: Avito -> Normalized: Avito
# Original: АО "Авито Финанс -> Normalized: АО "Авито Финанс
# Original: ООО "Кех Екоммерц -> Normalized: ООО "Кех Екоммерц
# Original: Avito -> Normalized: Avito
# Original: Новабев Групп -> Normalized: Новабев Групп
# Original: ПАО "Новабев Групп -> Normalized: ПАО "Новабев Групп
# Original: Ростелеком -> Normalized: Ростелеком
# Original: ЦФА -> Normalized: ЦФА
# Original: Альфа-банка -> Normalized: Альфа-банка
# Original: Ростелеком -> Normalized: Ростелеком
# Original: Альфа-банка -> Normalized: Альфа-банка
# Original: ВТБ -> Normalized: ВТБ
# Original: ВТБ -> Normalized: ВТБ
# Original: ВТБ -> Normalized: ВТБ
# Original: ВТБ -> Normalized: ВТБ
# Original: SFI -> Normalized: SFI
# Original: SFI (ПАО "ЭсЭфАй") -> Normalized: SFI (ПАО "ЭсЭфАй")
# Original: Европлан -> Normalized: Европлан
# Original: УК -> Normalized: УК
# Original: Мать и дитя -> Normalized: Мать и дитя
# Original: МКПАО "МД Медикал Груп" -> Normalized: МКПАО "МД Медикал Груп"
# Original: Мать и дитя -> Normalized: Мать и дитя
# Original: СИБУР -> Normalized: СИБУР
# Original: СИБУР -> Normalized: СИБУР
# Original: СИБУР -> Normalized: СИБУР
# Original: СИБУРа -> Normalized: СИБУРа
# Original: СИБУР -> Normalized: СИБУР
# Original: ПАО "ДжетЛенд Холдинг -> Normalized: ПАО "ДжетЛенд Холдинг
# Original: ДжетЛенд Холдинга -> Normalized: ДжетЛенд Холдинга
# Original: СПБ бирже -> Normalized: СПБ бирже
# Original: Русснефти -> Normalized: Русснефти
# Original: Русснефть -> Normalized: Русснефть
# Original: НК -> Normalized: НК
# Original: Ozon -> Normalized: Ozon
# Original: ЦФА -> Normalized: ЦФА
# Original: Озон Капитал -> Normalized: Озон Капитал
# Original: Ozon -> Normalized: Ozon
# Original: Озон Капитал -> Normalized: Озон Капитал
# Original: ПАО "Новабев Групп -> Normalized: ПАО "Новабев Групп
# Original: Новабев групп -> Normalized: Новабев групп
# Original: Новабев групп -> Normalized: Новабев групп
# Original: ВинЛаб -> Normalized: ВинЛаб
# Original: Лента -> Normalized: Лента
# Original: МКПАО "Лента -> Normalized: МКПАО "Лента
# Original: Ленты -> Normalized: Ленты
# Original: Группы Аренадата -> Normalized: Группы Аренадата
# Original: ПАО "Группа Аренадата -> Normalized: ПАО "Группа Аренадата
# Original: Arenadata -> Normalized: Arenadata
# Original: NIC -> Normalized: NIC
# Original: NIC -> Normalized: NIC
# Original: ПАО "ДжетЛенд Холдинг -> Normalized: ПАО "ДжетЛенд Холдинг
# Original: СПБ бирже -> Normalized: СПБ бирже
# Original: Черкизово -> Normalized: Черкизово
# Original: ПАО "Группа Черкизово -> Normalized: ПАО "Группа Черкизово
# Original: БК "Регион" -> Normalized: БК "Регион"
# Original: Россельхозбанк -> Normalized: Россельхозбанк
# Original: Черкизово -> Normalized: Черкизово
# Original: КС -> Normalized: КС
# Original: ГК "О'Кей -> Normalized: ГК "О'Кей
# Original: О'Кей -> Normalized: О'Кей
# Original: О'кей Груп -> Normalized: О'кей Груп
# Original: МКПАО -> Normalized: МКПАО
# Original: ПАО "Элемент" -> Normalized: ПАО "Элемент"
# Original: ПАО "Элемент" -> Normalized: ПАО "Элемент"
# Original: Элемента -> Normalized: Элемента
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Росбанк -> Normalized: Росбанк
# Original: ИФ -> Normalized: ИФ
# Original: Т -> Normalized: Т
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: ЛУКОЙЛа -> Normalized: ЛУКОЙЛа
# Original: ЛУКОЙЛа -> Normalized: ЛУКОЙЛа
# Original: ЛУКОЙЛа -> Normalized: ЛУКОЙЛа
# Original: ФПК "Гарант-инвест" -> Normalized: ФПК "Гарант-инвест"
# Original: Гарант-инвест -> Normalized: Гарант-инвест
# Original: Аэрофлота -> Normalized: Аэрофлота
# Original: Аэрофлота -> Normalized: Аэрофлота
# Original: Акрона -> Normalized: Акрона
# Original: Акрон -> Normalized: Акрон
# Original: Акрона -> Normalized: Акрона
# Original: Etalon Group -> Normalized: Etalon Group
# Original: CFO Etalon Group -> Normalized: CFO Etalon Group
# Original: ООО "СФО ТБ-3 -> Normalized: ООО "СФО ТБ-3
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Норильский никель -> Normalized: Норильский никель
# Original: ПАО "Норильский никель -> Normalized: ПАО "Норильский никель
# Original: Яндекса -> Normalized: Яндекса
# Original: Яндекс -> Normalized: Яндекс
# Original: Яндекс -> Normalized: Яндекс
# Original: Яндекса -> Normalized: Яндекса
# Original: ФПК "Гарант-инвест" -> Normalized: ФПК "Гарант-инвест"
# Original: Гарант-инвест -> Normalized: Гарант-инвест
# Original: Башнефти -> Normalized: Башнефти
# Original: Башнефти -> Normalized: Башнефти
# Original: Башнефти -> Normalized: Башнефти
# Original: X5 -> Normalized: X5
# Original: ПАО "Корпоративный центр "Икс 5 -> Normalized: ПАО "Корпоративный центр "Икс 5
# Original: Х5 -> Normalized: Х5
# Original: Санкт-Петербург -> Normalized: Санкт-Петербург
# Original: Санкт-Петербург -> Normalized: Санкт-Петербург
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: МКПАО "Т-Технологии -> Normalized: МКПАО "Т-Технологии
# Original: ТКС Холдинг -> Normalized: ТКС Холдинг
# Original: Росбанка -> Normalized: Росбанка
# Original: Банком России -> Normalized: Банком России
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: Санкт-Петербург -> Normalized: Санкт-Петербург
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: ТКС Холдинг -> Normalized: ТКС Холдинг
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: VK -> Normalized: VK
# Original: VK -> Normalized: VK
# Original: VK -> Normalized: VK
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: ТКС Холдинг -> Normalized: ТКС Холдинг
# Original: Т -> Normalized: Т
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: ММК -> Normalized: ММК
# Original: Магнитогорский металлургический комбинат -> Normalized: Магнитогорский металлургический комбинат
# Original: Интерфаксом -> Normalized: Интерфаксом
# Original: Брусника -> Normalized: Брусника
# Original: ООО "Брусника. Строительство и девелопмент -> Normalized: ООО "Брусника. Строительство и девелопмент
# Original: ФосАгро -> Normalized: ФосАгро
# Original: ФосАгро -> Normalized: ФосАгро
# Original: Globaltrans Investment PLC -> Normalized: Globaltrans Investment PLC
# Original: ВОСА -> Normalized: ВОСА
# Original: Московской биржи -> Normalized: Московской биржи
# Original: СПБ биржи -> Normalized: СПБ биржи
# Original: Национальном расчетном депозитарии -> Normalized: Национальном расчетном депозитарии
# Original: ПАО "СПБ Банк -> Normalized: ПАО "СПБ Банк
# Original: ООО "ГТИ Финанс -> Normalized: ООО "ГТИ Финанс
# Original: Интер РАО -> Normalized: Интер РАО
# Original: ПАО "Интер РАО -> Normalized: ПАО "Интер РАО
# Original: Русагро -> Normalized: Русагро
# Original: ГК "Русагро" -> Normalized: ГК "Русагро"
# Original: Русагро -> Normalized: Русагро
# Original: ГК "Русагро" -> Normalized: ГК "Русагро"
# Original: ПАО "Группа "Русагро -> Normalized: ПАО "Группа "Русагро
# Original: GDR -> Normalized: GDR
# Original: Ros Agro plc -> Normalized: Ros Agro plc
# Original: ПАО -> Normalized: ПАО
# Original: Инарктика -> Normalized: Инарктика
# Original: Норникеля -> Normalized: Норникеля
# Original: Норильского никеля -> Normalized: Норильского никеля
# Original: Норникеля -> Normalized: Норникеля
# Original: Норникелю -> Normalized: Норникелю
# Original: Инарктики -> Normalized: Инарктики
# Original: ПАО "Инарктика" -> Normalized: ПАО "Инарктика"
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Промсвязьбанка -> Normalized: Промсвязьбанка
# Original: Промсвязьбанка (ПСБ) -> Normalized: Промсвязьбанка (ПСБ)
# Original: Инарктика -> Normalized: Инарктика
# Original: ПАО "Инарктика" -> Normalized: ПАО "Инарктика"
# Original: Газпрома -> Normalized: Газпрома
# Original: ПАО "Газпром" -> Normalized: ПАО "Газпром"
# Original: ПАО -> Normalized: ПАО
# Original: ПАО "Газпром" -> Normalized: ПАО "Газпром"
# Original: ПАО "Газпром нефть -> Normalized: ПАО "Газпром нефть
# Original: ООО "Икс 5 Финанс -> Normalized: ООО "Икс 5 Финанс
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Альфа-банк -> Normalized: Альфа-банк
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ИБ "Синара -> Normalized: ИБ "Синара
# Original: Локо-банк -> Normalized: Локо-банк
# Original: Sber CIB -> Normalized: Sber CIB
# Original: СИБУРа -> Normalized: СИБУРа
# Original: СИБУРа -> Normalized: СИБУРа
# Original: ПАО "Лензолото" -> Normalized: ПАО "Лензолото"
# Original: Лензолото -> Normalized: Лензолото
# Original: Лензолото -> Normalized: Лензолото
# Original: ПАО "Софтлайн" -> Normalized: ПАО "Софтлайн"
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Софтлайна -> Normalized: Софтлайна
# Original: Минфин -> Normalized: Минфин
# Original: Белорусской валютно-фондовой бирже -> Normalized: Белорусской валютно-фондовой бирже
# Original: ФПК "Гарант-инвест" -> Normalized: ФПК "Гарант-инвест"
# Original: Санкт-Петербург -> Normalized: Санкт-Петербург
# Original: Домодедово -> Normalized: Домодедово
# Original: Домодедово Фьюэл Фасилитис" (ДФФ) -> Normalized: Домодедово Фьюэл Фасилитис" (ДФФ)
# Original: Домодедово -> Normalized: Домодедово
# Original: Борец -> Normalized: Борец
# Original: Группа ЛСР -> Normalized: Группа ЛСР
# Original: ПАО "Группа ЛСР -> Normalized: ПАО "Группа ЛСР
# Original: ПАО "Группа ЛСР -> Normalized: ПАО "Группа ЛСР
# Original: ПАО "М.Видео -> Normalized: ПАО "М.Видео
# Original: ПАО "М.Видео -> Normalized: ПАО "М.Видео
# Original: Московской бирже -> Normalized: Московской бирже
# Original: ПАО "Видео" -> Normalized: ПАО "Видео"
# Original: Видео-Эльдорадо -> Normalized: Видео-Эльдорадо
# Original: М.Видео -> Normalized: М.Видео
# Original: ПАО "М.Видео -> Normalized: ПАО "М.Видео
# Original: М.Видео-Эльдорадо -> Normalized: М.Видео-Эльдорадо
# Original: М.Видео -> Normalized: М.Видео
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: СНГ -> Normalized: СНГ
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: Совкомбанку ХКФ банка -> Normalized: Совкомбанку ХКФ банка
# Original: Хоум банк -> Normalized: Хоум банк
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: Совкомбанка -> Normalized: Совкомбанка
# Original: О'Кей -> Normalized: О'Кей
# Original: ООО "О'Кей -> Normalized: ООО "О'Кей
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: АО "Доринда" -> Normalized: АО "Доринда"
# Original: Яндекса -> Normalized: Яндекса
# Original: Яндекса -> Normalized: Яндекса
# Original: Делимобиль -> Normalized: Делимобиль
# Original: СЕО ПАО "Каршеринг Руссия -> Normalized: СЕО ПАО "Каршеринг Руссия
# Original: Делимобиль -> Normalized: Делимобиль
# Original: Делимобиля -> Normalized: Делимобиля
# Original: ПАО "Каршеринг Руссия -> Normalized: ПАО "Каршеринг Руссия
# Original: НОВАТЭКа -> Normalized: НОВАТЭКа
# Original: ПАО "НОВАТЭК" -> Normalized: ПАО "НОВАТЭК"
# Original: НОВАТЭКа -> Normalized: НОВАТЭКа
# Original: ПАО "Смарттехгрупп" -> Normalized: ПАО "Смарттехгрупп"
# Original: ПАО "Смарттехгрупп" (СТГ) -> Normalized: ПАО "Смарттехгрупп" (СТГ)
# Original: КарМани" (CarMoney) -> Normalized: КарМани" (CarMoney)
# Original: Банка России -> Normalized: Банка России
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: СТГ -> Normalized: СТГ
# Original: Промсвязьбанк (ПСБ) -> Normalized: Промсвязьбанк (ПСБ)
# Original: ПСБ -> Normalized: ПСБ
# Original: Смарттехгрупп -> Normalized: Смарттехгрупп
# Original: СТГ -> Normalized: СТГ
# Original: Промсвязьбанка -> Normalized: Промсвязьбанка
# Original: Ренессанс Страхование -> Normalized: Ренессанс Страхование
# Original: ПАО "Группа Ренессанс Страхование -> Normalized: ПАО "Группа Ренессанс Страхование
# Original: Ренессанс Страхование -> Normalized: Ренессанс Страхование
# Original: ПАО "Группа Ренессанс Страхование -> Normalized: ПАО "Группа Ренессанс Страхование
# Original: Селигдар -> Normalized: Селигдар
# Original: ПАО "Селигдар" -> Normalized: ПАО "Селигдар"
# Original: ВТБ Капитал трейдинг -> Normalized: ВТБ Капитал трейдинг
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: РА -> Normalized: РА
# Original: Диасофт -> Normalized: Диасофт
# Original: ПАО "Диасофт" -> Normalized: ПАО "Диасофт"
# Original: Диасофт -> Normalized: Диасофт
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: Российского национального коммерческого банка (РНКБ -> Normalized: Российского национального коммерческого банка (РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: ВТБ -> Normalized: ВТБ
# Original: ВТБ -> Normalized: ВТБ
# Original: ВТБ -> Normalized: ВТБ
# Original: РНКБ -> Normalized: РНКБ
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Банка России -> Normalized: Банка России
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Сбербанка -> Normalized: Сбербанка
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Полюса -> Normalized: Полюса
# Original: Полюса -> Normalized: Полюса
# Original: Полюса -> Normalized: Полюса
# Original: Мегафона -> Normalized: Мегафона
# Original: ПАО "Мегафон" -> Normalized: ПАО "Мегафон"
# Original: Мегафона -> Normalized: Мегафона
# Original: Группа ЛСР -> Normalized: Группа ЛСР
# Original: ПАО "Группа ЛСР -> Normalized: ПАО "Группа ЛСР
# Original: Группы ЛСР -> Normalized: Группы ЛСР
# Original: Черкизово -> Normalized: Черкизово
# Original: ПАО "Группа Черкизово -> Normalized: ПАО "Группа Черкизово
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Банка России -> Normalized: Банка России
# Original: БК "Регион" -> Normalized: БК "Регион"
# Original: ИК "Горизонт" -> Normalized: ИК "Горизонт"
# Original: Россельхозбанк -> Normalized: Россельхозбанк
# Original: Яндекса -> Normalized: Яндекса
# Original: МКПАО -> Normalized: МКПАО
# Original: Яндекс -> Normalized: Яндекс
# Original: Яндекса -> Normalized: Яндекса
# Original: БКС Холдинга -> Normalized: БКС Холдинга
# Original: ЦФА-платформ -> Normalized: ЦФА-платформ
# Original: Компанию Брокеркредитсервис (БКС) -> Normalized: Компанию Брокеркредитсервис (БКС)
# Original: ООО "Компания БКС" -> Normalized: ООО "Компания БКС"
# Original: БКС Мир инвестиций -> Normalized: БКС Мир инвестиций
# Original: БКС Холдинг -> Normalized: БКС Холдинг
# Original: БКС -> Normalized: БКС
# Original: Банк "Синара -> Normalized: Банк "Синара
# Original: ЦФА -> Normalized: ЦФА
# Original: Диасофт -> Normalized: Диасофт
# Original: ПАО "Диасофт" -> Normalized: ПАО "Диасофт"
# Original: Юнипро -> Normalized: Юнипро
# Original: ПАО "Юнипро" -> Normalized: ПАО "Юнипро"
# Original: Диасофт -> Normalized: Диасофт
# Original: ПАО "Диасофт" -> Normalized: ПАО "Диасофт"
# Original: Санкт-Петербург -> Normalized: Санкт-Петербург
# Original: Борец -> Normalized: Борец
# Original: Национальный расчетный депозитарий (НРД) -> Normalized: Национальный расчетный депозитарий (НРД)
# Original: НРД -> Normalized: НРД
# Original: Генпрокуратуры -> Normalized: Генпрокуратуры
# Original: HeadHunter -> Normalized: HeadHunter
# Original: CEO -> Normalized: CEO
# Original: HeadHunter (HH) -> Normalized: HeadHunter (HH)
# Original: HH -> Normalized: HH
# Original: МТС -> Normalized: МТС
# Original: ПАО "МТС" -> Normalized: ПАО "МТС"
# Original: ПАО "МТС" -> Normalized: ПАО "МТС"
# Original: Юрент -> Normalized: Юрент
# Original: МТС-банка -> Normalized: МТС-банка
# Original: МТС-банка -> Normalized: МТС-банка
# Original: Полюс -> Normalized: Полюс
# Original: ПАО "Полюс" -> Normalized: ПАО "Полюс"
# Original: Полюс -> Normalized: Полюс
# Original: Полюс -> Normalized: Полюс
# Original: Полюс -> Normalized: Полюс
# Original: Полюс -> Normalized: Полюс
# Original: Полюс -> Normalized: Полюс
# Original: Интерфаксом -> Normalized: Интерфаксом
# Original: Полюс -> Normalized: Полюс
# Original: Globaltrans -> Normalized: Globaltrans
# Original: Globaltrans Investment PLC -> Normalized: Globaltrans Investment PLC
# Original: Globaltrans -> Normalized: Globaltrans
# Original: Группа компаний "Южуралзолото" (ЮГК) -> Normalized: Группа компаний "Южуралзолото" (ЮГК)
# Original: Альфа-банк -> Normalized: Альфа-банк
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: ГК "О'Кей -> Normalized: ГК "О'Кей
# Original: О'Кей -> Normalized: О'Кей
# Original: МКПАО -> Normalized: МКПАО
# Original: Европлана -> Normalized: Европлана
# Original: Европлан -> Normalized: Европлан
# Original: Аэрофлот -> Normalized: Аэрофлот
# Original: Аэрофлота -> Normalized: Аэрофлота
# Original: Аэрофлот -> Normalized: Аэрофлот
# Original: Аэрофлота -> Normalized: Аэрофлота
# Original: Озон Фармацевтика -> Normalized: Озон Фармацевтика
# Original: ПАО "Озон Фармацевтика -> Normalized: ПАО "Озон Фармацевтика
# Original: ТМК -> Normalized: ТМК
# Original: Трубной металлургической компании -> Normalized: Трубной металлургической компании
# Original: ТМК -> Normalized: ТМК
# Original: ПАО "Россети" -> Normalized: ПАО "Россети"
# Original: ПАО "Россети" -> Normalized: ПАО "Россети"
# Original: МГКЛ -> Normalized: МГКЛ
# Original: Банк -> Normalized: Банк
# Original: ПАО "МГКЛ" -> Normalized: ПАО "МГКЛ"
# Original: Лазутин -> Normalized: Лазутин
# Original: МГКЛ -> Normalized: МГКЛ
# Original: МГКЛ -> Normalized: МГКЛ
# Original: МГКЛ -> Normalized: МГКЛ
# Original: СИБУРа -> Normalized: СИБУРа
# Original: СИБУР Холдинга -> Normalized: СИБУР Холдинга
# Original: СИБУРа -> Normalized: СИБУРа
# Original: Лента -> Normalized: Лента
# Original: МКПАО "Лента -> Normalized: МКПАО "Лента
# Original: Лента -> Normalized: Лента
# Original: ОВК -> Normalized: ОВК
# Original: ПАО "Научно-производственная корпорация "Объединенная вагонная компания" (НПК ОВК) -> Normalized: ПАО "Научно-производственная корпорация "Объединенная вагонная компания" (НПК ОВК)
# Original: ОВК -> Normalized: ОВК
# Original: ПАО "Элемент" -> Normalized: ПАО "Элемент"
# Original: ПАО "Элемент" -> Normalized: ПАО "Элемент"
# Original: ПАО "Элемент" -> Normalized: ПАО "Элемент"
# Original: ПАО -> Normalized: ПАО
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Элемента -> Normalized: Элемента
# Original: ПАО "Элемент" -> Normalized: ПАО "Элемент"
# Original: Мегафон -> Normalized: Мегафон
# Original: ПАО "Мегафон" -> Normalized: ПАО "Мегафон"
# Original: Мегафона -> Normalized: Мегафона
# Original: Новабев Групп -> Normalized: Новабев Групп
# Original: Новабев Групп -> Normalized: Новабев Групп
# Original: ПАО "Ламбумиз" -> Normalized: ПАО "Ламбумиз"
# Original: ПАО "Ламбумиз" -> Normalized: ПАО "Ламбумиз"
# Original: Газпрома -> Normalized: Газпрома
# Original: Газпрома -> Normalized: Газпрома
# Original: Газпрома -> Normalized: Газпрома
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: МКПАО "Т-Технологии" -> Normalized: МКПАО "Т-Технологии"
# Original: Татнефти -> Normalized: Татнефти
# Original: ПАО "Татнефть" -> Normalized: ПАО "Татнефть"
# Original: Интерфакса -> Normalized: Интерфакса
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Точка -> Normalized: Точка
# Original: МКООО -> Normalized: МКООО
# Original: Каталитик Пипл -> Normalized: Каталитик Пипл
# Original: АО "Точка" -> Normalized: АО "Точка"
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Росбанка -> Normalized: Росбанка
# Original: Интеррос -> Normalized: Интеррос
# Original: Каталитик пипл -> Normalized: Каталитик пипл
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: Интерроса -> Normalized: Интерроса
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: МКПАО "Т-Технологии" -> Normalized: МКПАО "Т-Технологии"
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: Т-Страхования -> Normalized: Т-Страхования
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: Софтлайна -> Normalized: Софтлайна
# Original: ПАО "Софтлайн" -> Normalized: ПАО "Софтлайн"
# Original: ПАО "Промомед" -> Normalized: ПАО "Промомед"
# Original: Группы Позитив -> Normalized: Группы Позитив
# Original: ПАО "Группа Позитив -> Normalized: ПАО "Группа Позитив
# Original: Positive Technologies -> Normalized: Positive Technologies
# Original: ИФ -> Normalized: ИФ
# Original: Henderson -> Normalized: Henderson
# Original: ПАО "Хэндерсон Фэшн Групп -> Normalized: ПАО "Хэндерсон Фэшн Групп
# Original: Лензолота -> Normalized: Лензолота
# Original: ПАО "Лензолото" -> Normalized: ПАО "Лензолото"
# Original: Лензолото -> Normalized: Лензолото
# Original: Распадской -> Normalized: Распадской
# Original: ПАО "Распадская" -> Normalized: ПАО "Распадская"
# Original: Распадской -> Normalized: Распадской
# Original: Распадская -> Normalized: Распадская
# ...
# Original: VK -> Normalized: VK
# Original: Интерфакса -> Normalized: Интерфакса
# Original: ПАО "Озон Фармацевтика -> Normalized: ПАО "Озон Фармацевтика
# Original: Лензолота -> Normalized: Лензолота
# Original: Лензолота -> Normalized: Лензолота
# Original: Лензолото -> Normalized: Лензолото
# Original: Лензолота -> Normalized: Лензолота
# Original: Промомеда -> Normalized: Промомеда
# Original: Промомед -> Normalized: Промомед
# Original: ПАО "Промомед" -> Normalized: ПАО "Промомед"
# Original: Промомеда -> Normalized: Промомеда
# Original: ГК "Самолет" -> Normalized: ГК "Самолет"
# Original: ГК "Самолет" -> Normalized: ГК "Самолет"
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ВТБ Капитал трейдинг -> Normalized: ВТБ Капитал трейдинг
# Original: АКРА -> Normalized: АКРА
# Original: Сбербанка -> Normalized: Сбербанка
# Original: Сбербанка -> Normalized: Сбербанка
# Original: Набсовет -> Normalized: Набсовет
# Original: Сбербанка -> Normalized: Сбербанка
# Original: Северсталь -> Normalized: Северсталь
# Original: Северсталь -> Normalized: Северсталь
# Original: Интерфаксом -> Normalized: Интерфаксом
# Original: Северстали -> Normalized: Северстали
# Original: Северстали -> Normalized: Северстали
# Original: Группы Астра -> Normalized: Группы Астра
# Original: ПАО "Группа Астра -> Normalized: ПАО "Группа Астра
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Группы Астра -> Normalized: Группы Астра
# Original: ПАО "Группа Астра -> Normalized: ПАО "Группа Астра
# Original: ООО "Астра Технологии -> Normalized: ООО "Астра Технологии
# Original: Группы Астра -> Normalized: Группы Астра
# Original: Группы Астра -> Normalized: Группы Астра
# Original: СИБУРа -> Normalized: СИБУРа
# Original: СИБУРа -> Normalized: СИБУРа
# Original: Группа ЛСР -> Normalized: Группа ЛСР
# Original: ПАО "Группа ЛСР -> Normalized: ПАО "Группа ЛСР
# Original: Яндекс -> Normalized: Яндекс
# Original: Яндекс -> Normalized: Яндекс
# Original: Банка России -> Normalized: Банка России
# Original: АО "Старт капитал -> Normalized: АО "Старт капитал
# Original: НОВАТЭКа -> Normalized: НОВАТЭКа
# Original: НОВАТЭКа -> Normalized: НОВАТЭКа
# Original: Южуралзолото -> Normalized: Южуралзолото
# Original: Южуралзолото" (ЮГК) -> Normalized: Южуралзолото" (ЮГК)
# Original: Интерфаксом -> Normalized: Интерфаксом
# Original: ЮГК -> Normalized: ЮГК
# Original: Т-Технологий -> Normalized: Т-Технологий
# Original: Роснефти -> Normalized: Роснефти
# Original: Роснефти -> Normalized: Роснефти
# Original: НК -> Normalized: НК
# Original: Роснефти -> Normalized: Роснефти
# Original: НК -> Normalized: НК
# Original: Роснефти -> Normalized: Роснефти
# Original: Группы ЛСР -> Normalized: Группы ЛСР
# Original: ПАО "Группа ЛСР -> Normalized: ПАО "Группа ЛСР
# Original: Северстали -> Normalized: Северстали
# Original: ПАО "Северсталь" -> Normalized: ПАО "Северсталь"
# Original: Северстали -> Normalized: Северстали
# Original: Etalon Group -> Normalized: Etalon Group
# Original: Etalon Group PLC -> Normalized: Etalon Group PLC
# Original: Эталон Груп -> Normalized: Эталон Груп
# Original: МКПАО -> Normalized: МКПАО
# Original: МКПАО -> Normalized: МКПАО
# Original: Московской бирже -> Normalized: Московской бирже
# Original: Etalon Group PLC -> Normalized: Etalon Group PLC
# Original: МКПАО "Эталон Груп -> Normalized: МКПАО "Эталон Груп
# Original: МКПАО -> Normalized: МКПАО
# Original: Globaltrans Investment PLC -> Normalized: Globaltrans Investment PLC
# Original: Raiffeisen Bank International AG -> Normalized: Raiffeisen Bank International AG
# Original: Financial Times -> Normalized: Financial Times
# Original: RBI -> Normalized: RBI
# Original: Райффайзенбанка -> Normalized: Райффайзенбанка
# Original: Bloomberg -> Normalized: Bloomberg
# Original: RBI -> Normalized: RBI
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Сбербанка -> Normalized: Сбербанка
# Original: ТМК -> Normalized: ТМК
# Original: Трубной металлургической компании" (ТМК) -> Normalized: Трубной металлургической компании" (ТМК)
# Original: ТМК -> Normalized: ТМК
# Original: ТМК -> Normalized: ТМК
# Original: ИБ "Синара -> Normalized: ИБ "Синара
# Original: ТМК -> Normalized: ТМК
# Original: Моих инвестиций -> Normalized: Моих инвестиций
# Original: Яндекса -> Normalized: Яндекса
# Original: МКПАО "Яндекс -> Normalized: МКПАО "Яндекс
# Original: АЛРОСА -> Normalized: АЛРОСА
# Original: АЛРОСА -> Normalized: АЛРОСА
# Original: ПАО "Ростелеком" -> Normalized: ПАО "Ростелеком"
# Original: Data Fusion -> Normalized: Data Fusion
# Original: Ростелекома -> Normalized: Ростелекома
# Original: LfL-выручку -> Normalized: LfL-выручку
# Original: ПАО "Корпоративный центр ИКС 5 -> Normalized: ПАО "Корпоративный центр ИКС 5
# Original: Яндекс -> Normalized: Яндекс
# Original: Санкт-Петербург -> Normalized: Санкт-Петербург
# Original: Санкт-Петербург -> Normalized: Санкт-Петербург
# Original: ПАО "Диасофт" -> Normalized: ПАО "Диасофт"
# Original: Диасофт -> Normalized: Диасофт
# Original: Газпромбанк Инвестиции -> Normalized: Газпромбанк Инвестиции
# Original: Диасофта -> Normalized: Диасофта
# Original: Диасофту -> Normalized: Диасофту
# Original: Газпром -> Normalized: Газпром
# Original: Газпром капитал -> Normalized: Газпром капитал
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ВТБ Капитал трейдинг -> Normalized: ВТБ Капитал трейдинг
# Original: Sber CIB -> Normalized: Sber CIB
# Original: ПАО "Газпром" -> Normalized: ПАО "Газпром"
# Original: Банка России -> Normalized: Банка России
# Original: Смарттехгрупп -> Normalized: Смарттехгрупп
# Original: ПСБ -> Normalized: ПСБ
# Original: ПАО "Смарттехгрупп" (СТГ) -> Normalized: ПАО "Смарттехгрупп" (СТГ)
# Original: КарМани" (CarMoney) -> Normalized: КарМани" (CarMoney)
# Original: ПСБ -> Normalized: ПСБ
# Original: ПИК -> Normalized: ПИК
# Original: ПИК -> Normalized: ПИК
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: ПИК -> Normalized: ПИК
# Original: ЦФА -> Normalized: ЦФА
# Original: ООО "Балтийский лизинг -> Normalized: ООО "Балтийский лизинг
# Original: Альфа-банка -> Normalized: Альфа-банка
# Original: Полюса -> Normalized: Полюса
# Original: Полюса -> Normalized: Полюса
# Original: УК -> Normalized: УК
# Original: Кристалл -> Normalized: Кристалл
# Original: Калужский ликеро-водочный завода "Кристалл" ("КЛВЗ Кристалл -> Normalized: Калужский ликеро-водочный завода "Кристалл" ("КЛВЗ Кристалл
# Original: ПАО "АГ Кристалл -> Normalized: ПАО "АГ Кристалл
# Original: ПАО -> Normalized: ПАО
# Original: Группа Аренадата -> Normalized: Группа Аренадата
# Original: ПАО "Группа Аренадата -> Normalized: ПАО "Группа Аренадата
# Original: СД Henderson -> Normalized: СД Henderson
# Original: ПАО "Хэндерсон Фэшн Групп -> Normalized: ПАО "Хэндерсон Фэшн Групп
# Original: ПИК -> Normalized: ПИК
# Original: ПИК -> Normalized: ПИК
# Original: Мегафона -> Normalized: Мегафона
# Original: ПАО "Мегафон" -> Normalized: ПАО "Мегафон"
# Original: Мегафона -> Normalized: Мегафона
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ЦФА -> Normalized: ЦФА
# Original: Газпромбанк (ГПБ) -> Normalized: Газпромбанк (ГПБ)
# Original: Национального расчетного депозитария (НРД) -> Normalized: Национального расчетного депозитария (НРД)
# Original: НРД -> Normalized: НРД
# Original: Segezha -> Normalized: Segezha
# Original: Банк ВТБ -> Normalized: Банк ВТБ
# Original: Segezha Group -> Normalized: Segezha Group
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Segezha -> Normalized: Segezha
# Original: Segezha -> Normalized: Segezha
# Original: Segezha -> Normalized: Segezha
# Original: Интерфакса -> Normalized: Интерфакса
# Original: Segezha -> Normalized: Segezha
# Original: Сбербанк -> Normalized: Сбербанк
# Original: ВТБ -> Normalized: ВТБ
# Original: Альфа-банк -> Normalized: Альфа-банк
# Original: МКБ -> Normalized: МКБ
# Original: Segezha -> Normalized: Segezha
# Original: АЛРОСА -> Normalized: АЛРОСА
# Original: АЛРОСА -> Normalized: АЛРОСА
# Original: Эталон -> Normalized: Эталон
# Original: АО "Эталон-финанс" -> Normalized: АО "Эталон-финанс"
# Original: Альфа-банк -> Normalized: Альфа-банк
# Original: ВТБ Капитал трейдинг -> Normalized: ВТБ Капитал трейдинг
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: Джи Ай Солюшенс -> Normalized: Джи Ай Солюшенс
# Original: ДОМ.РФ -> Normalized: ДОМ.РФ
# Original: Держава -> Normalized: Держава
# Original: Синара -> Normalized: Синара
# Original: Sber CIB -> Normalized: Sber CIB
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: Т-Технологии -> Normalized: Т-Технологии
# Original: РА -> Normalized: РА
# Original: Роснано -> Normalized: Роснано
# Original: АО "Роснано" -> Normalized: АО "Роснано"
# Original: Национального расчетного депозитария (НРД) -> Normalized: Национального расчетного депозитария (НРД)
# Original: НРД -> Normalized: НРД
# Original: Роснано -> Normalized: Роснано
# Original: Яндекса -> Normalized: Яндекса
# Original: МКПАО -> Normalized: МКПАО
# Original: Яндекс -> Normalized: Яндекс
# Original: Яндекса -> Normalized: Яндекса
# Original: Яндекса -> Normalized: Яндекса
# Original: ООО "ЕСОП СПВ -> Normalized: ООО "ЕСОП СПВ
# Original: Делимобиля -> Normalized: Делимобиля
# Original: ПАО "Каршеринг Руссия -> Normalized: ПАО "Каршеринг Руссия
# Original: ПАО "Каршеринг Руссия -> Normalized: ПАО "Каршеринг Руссия
# Original: СЕО компании -> Normalized: СЕО компании
# Original: Газпром -> Normalized: Газпром
# Original: ООО "Газпром капитал -> Normalized: ООО "Газпром капитал
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ВТБ Капитал Трейдинг -> Normalized: ВТБ Капитал Трейдинг
# Original: Sber CIB -> Normalized: Sber CIB
# Original: ПАО "Газпром" -> Normalized: ПАО "Газпром"
# Original: Globaltrans -> Normalized: Globaltrans
# Original: УК ЗПИФа "Трансатлант -> Normalized: УК ЗПИФа "Трансатлант
# Original: Globaltrans Investment PLC -> Normalized: Globaltrans Investment PLC
# Original: Управляющей компании ЗПИФа "Трансатлант -> Normalized: Управляющей компании ЗПИФа "Трансатлант
# Original: Globaltrans -> Normalized: Globaltrans
# Original: Globaltrans -> Normalized: Globaltrans
# Original: Татнефти -> Normalized: Татнефти
# Original: Татнефти -> Normalized: Татнефти
# Original: Интерфаксом -> Normalized: Интерфаксом
# Original: ИБ "Синара -> Normalized: ИБ "Синара
# Original: БКС Мир инвестиций -> Normalized: БКС Мир инвестиций
# Original: Татнефть -> Normalized: Татнефть
# Original: ГОСА -> Normalized: ГОСА
# Original: ООО "Тами и Ко -> Normalized: ООО "Тами и Ко
# Original: ПАО "Хэндерсон Фэшн Групп -> Normalized: ПАО "Хэндерсон Фэшн Групп
# Original: Henderson -> Normalized: Henderson
# Original: Норникель -> Normalized: Норникель
# Original: КС -> Normalized: КС
# Original: ПАО "ГМК "Норильский никель -> Normalized: ПАО "ГМК "Норильский никель
# Original: КС -> Normalized: КС
# Original: АО "Старт капитал -> Normalized: АО "Старт капитал
# Original: Новабев групп -> Normalized: Новабев групп
# Original: ПАО "Новабев групп -> Normalized: ПАО "Новабев групп
# Original: Яндекс -> Normalized: Яндекс
# Original: Яндекс -> Normalized: Яндекс
# Original: МТС -> Normalized: МТС
# Original: ПАО "МТС" -> Normalized: ПАО "МТС"
# Original: ПАО "МТС" -> Normalized: ПАО "МТС"
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Сбербанк -> Normalized: Сбербанк
# Original: Селигдар -> Normalized: Селигдар
# Original: АЛРОСА -> Normalized: АЛРОСА
# Original: Якутия 24 -> Normalized: Якутия 24
# Original: АЛРОСА -> Normalized: АЛРОСА
# Original: Селигдар -> Normalized: Селигдар
# Original: ПАО "Селигдар" -> Normalized: ПАО "Селигдар"
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ВТБ Капитал трейдинг -> Normalized: ВТБ Капитал трейдинг
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: Яндекс -> Normalized: Яндекс
# Original: Яндекс -> Normalized: Яндекс
# Original: Интерфаксу -> Normalized: Интерфаксу
# Original: Банка России -> Normalized: Банка России
# Original: АО "Старт капитал -> Normalized: АО "Старт капитал
# Original: Московской биржей -> Normalized: Московской биржей
# Original: VK -> Normalized: VK
# Original: ЗПИФы -> Normalized: ЗПИФы
# Original: VK (МКПАО "ВК") -> Normalized: VK (МКПАО "ВК")
# Original: VK -> Normalized: VK
# Original: VK -> Normalized: VK
# Original: VK -> Normalized: VK
# Original: Банком России -> Normalized: Банком России
# Original: Группа Позитив -> Normalized: Группа Позитив
# Original: ПАО "Группа Позитив -> Normalized: ПАО "Группа Позитив
# Original: Positive Technologies -> Normalized: Positive Technologies
# Original: Интерфакса -> Normalized: Интерфакса
# Original: Группы Позитив -> Normalized: Группы Позитив
# Original: ПАО "Группа Позитив -> Normalized: ПАО "Группа Позитив
# Original: ПАО -> Normalized: ПАО
# Original: Группа Позитив -> Normalized: Группа Позитив
# Original: ПАО -> Normalized: ПАО
# Original: ПАО "Озон Фармацевтика -> Normalized: ПАО "Озон Фармацевтика
# Original: Группы Позитив -> Normalized: Группы Позитив
# Original: ПАО "Группа Позитив -> Normalized: ПАО "Группа Позитив
# Original: Группа Астра -> Normalized: Группа Астра
# Original: ПАО "Группа Астра -> Normalized: ПАО "Группа Астра
# Original: Татнефти -> Normalized: Татнефти
# Original: ПАО "Татнефть" -> Normalized: ПАО "Татнефть"
# Original: Татнефть -> Normalized: Татнефть
# Original: Татнефти -> Normalized: Татнефти
# Original: ПАО "Группа Астра -> Normalized: ПАО "Группа Астра
# Original: Менеджмент "Группы Астра -> Normalized: Менеджмент "Группы Астра
# Original: Группы Астра -> Normalized: Группы Астра
# Original: Новабев групп -> Normalized: Новабев групп
# Original: Winelab -> Normalized: Winelab
# Original: ВинЛаб -> Normalized: ВинЛаб
# Original: IVA Technologies -> Normalized: IVA Technologies
# Original: IVA Technologies -> Normalized: IVA Technologies
# Original: ПАО "ИВА" -> Normalized: ПАО "ИВА"
# Original: Группа Астра -> Normalized: Группа Астра
# Original: ПАО "Группа Астра -> Normalized: ПАО "Группа Астра
# Original: Интерфакса -> Normalized: Интерфакса
# Original: ООО "Агро зерно Юг" -> Normalized: ООО "Агро зерно Юг"
# Original: ИК "Иволга капитал -> Normalized: ИК "Иволга капитал
# Original: ПАО "РусГидро" -> Normalized: ПАО "РусГидро"
# Original: РусГидро -> Normalized: РусГидро
# Original: РусГидро -> Normalized: РусГидро
# Original: РусГидро -> Normalized: РусГидро
# Original: Хэдхантер Груп ПиЭлСи -> Normalized: Хэдхантер Груп ПиЭлСи
# Original: МКАО -> Normalized: МКАО
# Original: МКПАО "Хэдхантер" - МКАО "Хэдхантер Груп ПиЭлСи -> Normalized: МКПАО "Хэдхантер" - МКАО "Хэдхантер Груп ПиЭлСи
# Original: HH -> Normalized: HH
# Original: HeadHunter Group PLC) -> Normalized: HeadHunter Group PLC)
# Original: МКАО -> Normalized: МКАО
# Original: HH -> Normalized: HH
# Original: АДР -> Normalized: АДР
# Original: МКАО -> Normalized: МКАО
# Original: МКАО -> Normalized: МКАО
# Original: ФосАгро -> Normalized: ФосАгро
# Original: ПАО "ФосАгро" -> Normalized: ПАО "ФосАгро"
# Original: Газпромбанк -> Normalized: Газпромбанк
# Original: ПАО "Аптечная сеть 36,6" -> Normalized: ПАО "Аптечная сеть 36,6"
# Original: Альфа-банк -> Normalized: Альфа-банк
# Original: Совкомбанк -> Normalized: Совкомбанк
# Original: ЕвроТранса -> Normalized: ЕвроТранса
# Original: ПАО "ЕвроТранс" -> Normalized: ПАО "ЕвроТранс"
# Original: Трасса -> Normalized: Трасса
# Original: ЕвроТранса -> Normalized: ЕвроТранса
# Original: ИФ -> Normalized: ИФ
# Original: Роснано -> Normalized: Роснано
# Original: АО "Роснано" -> Normalized: АО "Роснано"
# Original: Роснано -> Normalized: Роснано
# Original: Интерфакс -> Normalized: Интерфакс
# Original: Роснано -> Normalized: Роснано
# Original: Новабев Групп -> Normalized: Новабев Групп
# Original: Winelab** -> Normalized: Winelab**
# Original: ВинЛаб -> Normalized: ВинЛаб
# Original: Циан -> Normalized: Циан
# Original: МКПАО -> Normalized: МКПАО
# Original: МКПАО "Циан -> Normalized: МКПАО "Циан
# Original: Циан -> Normalized: Циан
# Original: МКПАО -> Normalized: МКПАО
# Original: Интерфакса -> Normalized: Интерфакса
# Original: Циан -> Normalized: Циан
# Original: ГК "О'Кей -> Normalized: ГК "О'Кей
# Original: О'Кей -> Normalized: О'Кей
# Original: O`KEY Group -> Normalized: O`KEY Group
# Original: О'Кей -> Normalized: О'Кей
# Original: ДА! -> Normalized: ДА!
# Original: О'Кей -> Normalized: О'Кей
# Original: 3,66x -> Normalized: 3,66x
#  C:\Users\Ольга\ВКР Карпенко\Inter_fax_data\filtered_with_tickers_2.xlsx

# %% [markdown]
# ## Manual verification of results

# %%
df_filtered = pd.read_excel(r"C:\Users\Карпенко\ВКР Карпенко\data markup\filtered_with_tickers_2.xlsx")


total = len(df_filtered)
correct = df_filtered['Correct'].sum()
accuracy = correct / total

print(f"📊 Accuracy (точность): {accuracy:.4f} ({correct}/{total})")
# Out:
# 📊 Accuracy (точность): 0.9208 (349/379)
